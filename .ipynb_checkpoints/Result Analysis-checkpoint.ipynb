# %%
import glob, os
os.environ['NUMEXPR_MAX_THREADS'] = '32'
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.utils.coco as fouc
import fiftyone.core.clips as focc
import fiftyone.utils.eval as foue
import fiftyone.utils.eval.utils as foueu
import fiftyone.brain as fob
from fiftyone import ViewField as F
import json
import cv2
import numpy as np

# Ensure that plotly.js is downloaded
import plotly.offline as po
po.init_notebook_mode(connected=True)

# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Setup Visualization
# ### Load Dataset and Resnet101-Imagenet weight

# %%
# load coco train dataset
coco_train_data_path = f"./datasets/coco/train2017"
coco_train_labels_path = f"./datasets/coco/annotations/instances_train2017.json"
coco_train_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=coco_train_data_path,
    labels_path=coco_train_labels_path,
    name='coco_train',
    label_field='ground_truth'
)
# Out:
#  100% |███████████| 118287/118287 [11.9m elapsed, 0s remaining, 168.4 samples/s]

# %%
#load coco validation dataset
coco_val_data_path = f"./datasets/coco/val2017"
coco_val_labels_path = f"./datasets/coco/annotations/instances_val2017.json"
coco_val_dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=coco_val_data_path,
    labels_path=coco_val_labels_path,
    name='coco_val',
    label_field='ground_truth'
)
# Out:
#  100% |███████████████| 5000/5000 [32.0s elapsed, 0s remaining, 174.6 samples/s]

# %%
# dataset = fo.load_dataset('coco_train')
dataset = fo.load_dataset('coco_val')

model = foz.load_zoo_model("resnet101-imagenet-torch")

# %%
with open("./output/coco_10.0/ubteacher_weights/inference/coco_instances_results.json",'r') as f:
    a = json.load(f)
classes = dataset.default_classes
# Convert to [top-left-x, top-left-y, width, height]
# in relative coordinates in [0, 1] x [0, 1]

with fo.ProgressBar() as pb:
    for sample in pb(dataset):
        w=sample.metadata.width
        h=sample.metadata.height
        img_id = str(int(os.path.splitext(os.path.basename(sample.filepath))[0]))
        detections = []
        for d in a:
            if d['image_id'] == int(img_id):
                
                abs_x, abs_y, abs_w, abs_h = d['bbox']
                if abs_w > 1.0 or abs_h > 1.0:
                    rel_box = [abs_x / w, abs_y / h, abs_w / w, abs_h / h]
                
                detections.append(fo.Detection(
                    label=classes[d['category_id']],
                    bounding_box=rel_box,
                    confidence=d['score']
                ))
        sample["predictions"] = fo.Detections(detections=detections)
        sample.save()
# Out:
#    0% |/--------------|    0/5000 [18.3ms elapsed, ? remaining, ? samples/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-342e7be387ff> in <module>
#      15
#      16                 abs_x, abs_y, abs_w, abs_h = d['bbox']
# ---> 17                 if x2 > 1.0 or y2 > 1.0:
#      18                     rel_box = [abs_x / w, abs_y / h, abs_w / w, abs_h / h]
#      19
#
# NameError: name 'x2' is not defined

# %%
a[1]
# Out:
# {'image_id': 139,
#  'category_id': 1,
#  'bbox': [425.326416015625,
#   160.98619079589844,
#   40.470306396484375,
#   122.19172668457031],
#  'score': 0.967115581035614}

# %%
session = fo.launch_app(dataset,port=15555)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:15555/?notebook=true&handleId=09a21d1b-fd69-45e2-9dc7-4c682fe7d640"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
with fo.ProgressBar() as pb:
    for sample in pb(dataset):
        print(sample)
        break
# Out:
# <Sample: {
#     'id': '62453f8177ddd47d6aa4ae21',
#     'media_type': 'image',
#     'filepath': '/workspace/unbiased-teacher/datasets/coco/val2017/000000000139.jpg',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 426,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae0d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'potted plant',
#                 'bounding_box': BaseList([
#                     0.37028125,
#                     0.3345305164319249,
#                     0.038593749999999996,
#                     0.16314553990610328,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae0e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'tv',
#                 'bounding_box': BaseList([
#                     0.010984375000000001,
#                     0.39380281690140845,
#                     0.23331249999999998,
#                     0.22269953051643193,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'electronic',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae0f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'tv',
#                 'bounding_box': BaseList([
#                     0.8706406250000001,
#                     0.491056338028169,
#                     0.127109375,
#                     0.18481220657276995,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'electronic',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae10',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.56090625,
#                     0.5118544600938968,
#                     0.0875,
#                     0.24138497652582158,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae11',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.454203125,
#                     0.5117370892018779,
#                     0.096609375,
#                     0.2311737089201878,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae12',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.645625,
#                     0.5234976525821596,
#                     0.047140625000000005,
#                     0.19098591549295774,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae13',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.4959375,
#                     0.5146478873239437,
#                     0.03371875,
#                     0.02720657276995305,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae14',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.645,
#                     0.3699765258215963,
#                     0.082890625,
#                     0.3239671361502347,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae15',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.600671875,
#                     0.40424882629107983,
#                     0.023625,
#                     0.08389671361502347,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'person',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae16',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'microwave',
#                 'bounding_box': BaseList([
#                     0.80034375,
#                     0.482981220657277,
#                     0.02303125,
#                     0.037488262910798126,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'appliance',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae17',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'refrigerator',
#                 'bounding_box': BaseList([
#                     0.77046875,
#                     0.40924882629107984,
#                     0.031703125,
#                     0.2542488262910798,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'appliance',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae18',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'book',
#                 'bounding_box': BaseList([
#                     0.944953125,
#                     0.7180516431924883,
#                     0.02240625,
#                     0.10730046948356808,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae19',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'book',
#                 'bounding_box': BaseList([
#                     0.9581875,
#                     0.7235680751173709,
#                     0.020125,
#                     0.10901408450704225,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'clock',
#                 'bounding_box': BaseList([
#                     0.699640625,
#                     0.2843192488262911,
#                     0.021828125,
#                     0.05136150234741784,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.8579062499999999,
#                     0.7263615023474178,
#                     0.0573125,
#                     0.2104929577464789,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.5480625,
#                     0.4902347417840376,
#                     0.017765625,
#                     0.05293427230046949,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.644140625,
#                     0.514131455399061,
#                     0.015046875000000001,
#                     0.029389671361502348,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.37693750000000004,
#                     0.4577230046948357,
#                     0.022218750000000002,
#                     0.04138497652582159,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae1f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.526234375,
#                     0.46830985915492956,
#                     0.015203125000000001,
#                     0.039272300469483566,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'indoor',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '62453f8177ddd47d6aa4ae20',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dining table',
#                 'bounding_box': BaseList([
#                     0.5018906249999999,
#                     0.5427699530516432,
#                     0.19618750000000001,
#                     0.20875586854460096,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'furniture',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
#     'coco_baseline': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf2',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     375.2504577636719,
#                     214.46340942382812,
#                     69.166748046875,
#                     86.93325805664062,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9980272650718689,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf3',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     425.326416015625,
#                     160.98619079589844,
#                     40.470306396484375,
#                     122.19172668457031,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.967115581035614,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     548.1228637695312,
#                     321.5480041503906,
#                     37.5628662109375,
#                     79.93222045898438,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9268063902854919,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf5',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'potted plant',
#                 'bounding_box': BaseList([
#                     225.15921020507812,
#                     175.80357360839844,
#                     44.059906005859375,
#                     36.96440124511719,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9178630113601685,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     297.1609191894531,
#                     222.99789428710938,
#                     85.0484619140625,
#                     89.8428955078125,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.8649430871009827,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf7',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'tv',
#                 'bounding_box': BaseList([
#                     10.015143394470215,
#                     184.15951538085938,
#                     144.28976440429688,
#                     75.2210693359375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.7328959703445435,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf8',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     211.8543701171875,
#                     227.30227661132812,
#                     97.15228271484375,
#                     75.61993408203125,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6982575058937073,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cf9',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     168.54843139648438,
#                     233.4514923095703,
#                     17.471527099609375,
#                     33.87480163574219,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6707756519317627,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cfa',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     548.7140502929688,
#                     303.99517822265625,
#                     41.3861083984375,
#                     99.5498046875,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6410843729972839,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cfb',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'clock',
#                 'bounding_box': BaseList([
#                     448.4686279296875,
#                     120.65382385253906,
#                     12.822174072265625,
#                     21.950180053710938,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6148779988288879,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cfc',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     46.17437744140625,
#                     207.90159606933594,
#                     16.640705108642578,
#                     33.082183837890625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.54923415184021,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cfd',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dining table',
#                 'bounding_box': BaseList([
#                     301.119384765625,
#                     217.12049865722656,
#                     95.80673217773438,
#                     84.41194152832031,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.4715048670768738,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cfe',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     448.8021240234375,
#                     119.63935852050781,
#                     12.6181640625,
#                     23.346649169921875,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.4330746829509735,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2cff',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     53.82215118408203,
#                     210.56007385253906,
#                     9.031723022460938,
#                     30.810775756835938,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.25942179560661316,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d00',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     428.3612365722656,
#                     231.00669860839844,
#                     19.208282470703125,
#                     69.19383239746094,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.2435956746339798,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d01',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     46.06968688964844,
#                     209.48719787597656,
#                     16.127628326416016,
#                     31.64208984375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.2131267786026001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d02',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'laptop',
#                 'bounding_box': BaseList([
#                     0.0,
#                     174.74020385742188,
#                     149.45533752441406,
#                     91.78414916992188,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.15988820791244507,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d03',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cup',
#                 'bounding_box': BaseList([
#                     167.98768615722656,
#                     233.09727478027344,
#                     18.191268920898438,
#                     31.762832641601562,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.14429651200771332,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d04',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     306.0847473144531,
#                     217.86004638671875,
#                     146.16574096679688,
#                     92.53787231445312,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.08795550465583801,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d05',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     368.1313781738281,
#                     228.70407104492188,
#                     22.44476318359375,
#                     83.48919677734375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.08155717700719833,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '624548a577ddd47d6aab2d06',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'oven',
#                 'bounding_box': BaseList([
#                     115.2374267578125,
#                     263.958740234375,
#                     111.52134704589844,
#                     64.1634521484375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.07810626178979874,
#                 'index': None,
#             }>,
#         ]),
#     }>,
#     'predictions': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e47',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.5863288402557373,
#                     0.5034352333892679,
#                     0.10807304382324219,
#                     0.20406868088413294,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9980272650718689,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e48',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.6645725250244141,
#                     0.37790185632840007,
#                     0.06323485374450684,
#                     0.286835039165658,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.967115581035614,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e49',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     0.8564419746398926,
#                     0.7548075214797902,
#                     0.058691978454589844,
#                     0.1876343203262544,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9268063902854919,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'potted plant',
#                 'bounding_box': BaseList([
#                     0.35181126594543455,
#                     0.4126844450901372,
#                     0.06884360313415527,
#                     0.08677089494158964,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.9178630113601685,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.4643139362335205,
#                     0.5234692354157497,
#                     0.13288822174072265,
#                     0.21089881574603872,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.8649430871009827,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'tv',
#                 'bounding_box': BaseList([
#                     0.01564866155385971,
#                     0.43229933187995156,
#                     0.22545275688171387,
#                     0.1765752801313087,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.7328959703445435,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.3310224533081055,
#                     0.5335734192754181,
#                     0.15180044174194335,
#                     0.17751158235218603,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6982575058937073,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.26335692405700684,
#                     0.5480081979097895,
#                     0.027299261093139647,
#                     0.07951831369892533,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6707756519317627,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e4f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.8573657035827636,
#                     0.7136037047480194,
#                     0.0646657943725586,
#                     0.23368498752934272,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6410843729972839,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e50',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'clock',
#                 'bounding_box': BaseList([
#                     0.7007322311401367,
#                     0.2832249386209837,
#                     0.020034646987915038,
#                     0.051526244257537414,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.6148779988288879,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e51',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     0.07214746475219727,
#                     0.4880319156557182,
#                     0.026001101732254027,
#                     0.07765770853964936,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.54923415184021,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e52',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'dining table',
#                 'bounding_box': BaseList([
#                     0.47049903869628906,
#                     0.5096725320592173,
#                     0.14969801902770996,
#                     0.19815009748431997,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.4715048670768738,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e53',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'vase',
#                 'bounding_box': BaseList([
#                     0.7012533187866211,
#                     0.280843564602131,
#                     0.01971588134765625,
#                     0.05480434077446449,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.4330746829509735,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e54',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'bottle',
#                 'bounding_box': BaseList([
#                     0.08409711122512817,
#                     0.4942724738322513,
#                     0.014112067222595216,
#                     0.0723257646874083,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.25942179560661316,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e55',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.6693144321441651,
#                     0.5422692455596207,
#                     0.03001294136047363,
#                     0.16242683661375806,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.2435956746339798,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e56',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'person',
#                 'bounding_box': BaseList([
#                     0.07198388576507568,
#                     0.4917539856243581,
#                     0.025199419260025023,
#                     0.07427720620598592,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.2131267786026001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e57',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'laptop',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.41018827196577906,
#                     0.23352396488189697,
#                     0.21545574922516872,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.15988820791244507,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e58',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'cup',
#                 'bounding_box': BaseList([
#                     0.2624807596206665,
#                     0.5471767013621442,
#                     0.02842385768890381,
#                     0.07456064000375953,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.14429651200771332,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e59',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.478257417678833,
#                     0.5114085595932365,
#                     0.22838397026062013,
#                     0.21722505238134537,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.08795550465583801,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e5a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'chair',
#                 'bounding_box': BaseList([
#                     0.5752052783966064,
#                     0.5368640165373753,
#                     0.035069942474365234,
#                     0.19598402999376466,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.08155717700719833,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '6245504977ddd47d6ab77e5b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'oven',
#                 'bounding_box': BaseList([
#                     0.18005847930908203,
#                     0.6196214559492371,
#                     0.17425210475921632,
#                     0.15061843227332747,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.07810626178979874,
#                 'index': None,
#             }>,
#         ]),
#     }>,
# }>
#    0% |/--------------|    0/5000 [175.6ms elapsed, ? remaining, ? samples/s]

# %% [markdown]
# ### Confusion matrix

# %%
# Evaluate detections in the `predictions` field
# classwise=False, match highest IOU prediction with gt then if class match true-positive else false-positive
# classwise=True, first find prediction bbox same label with gt and IOU>thresh, then if prediction exists, t-p
confusion_results = dataset.evaluate_detections("predictions", gt_field="ground_truth",classes=classes,method="coco",
    classwise=False)

# Plot confusion matrix
confusion_plot = confusion_results.plot_confusion_matrix(classes=classes)
confusion_plot.show()
# Out:
# Evaluating detections...
#  100% |███████████████| 5000/5000 [1.9m elapsed, 0s remaining, 45.8 samples/s]
# FigureWidget({
#     'data': [{'mode': 'markers',
#               'opacity': 0.1,
#               'type': 'scatter',…

# %%
from sklearn.preprocessing import normalize
temp = confusion_results.confusion_matrix(classes=classes, include_other=False)
normed_matrix = normalize(temp, axis=1, norm='l1')
fo.core.plots.matplotlib.plot_confusion_matrix(normed_matrix, labels=classes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-92daab748dcf> in <module>
#       2 temp = confusion_results.confusion_matrix(classes=classes, include_other=False)
#       3 normed_matrix = normalize(temp, axis=1, norm='l1')
# ----> 4 fo.core.plots.matplotlib.plot_confusion_matrix(normed_matrix, labels=classes)
#
# AttributeError: module 'fiftyone.core.plots' has no attribute 'matplotlib'

# %%
# Plot confusion matrix
confusion_plot = confusion_results.plot_confusion_matrix(classes=classes,include_other=False, include_missing=False)
confusion_plot.show()
# Out:
# FigureWidget({
#     'data': [{'mode': 'markers',
#               'opacity': 0.1,
#               'type': 'scatter',…

# %%
temp = confusion_results.confusion_matrix(classes=classes, include_other=False)

# %%
from sklearn.preprocessing import normalize

# %%
normed_matrix = normalize(temp, axis=1, norm='l1')
print(normed_matrix)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=normed_matrix, display_labels=classes)
disp.plot()
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 9.84983060e-01 1.83133413e-04 ... 3.66266825e-04
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.89655172e-02 6.96551724e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 1.22950820e-01 0.00000000e+00 ... 7.37704918e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 7.50000000e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.81818182e-01]]
# <img src="data:image/png;base64,..." width="640">

# %%
# Connect to FiftyOne App for Interaction
session.plots.attach(confusion_plot)

# Interactive Mode
confusion_plot.selection_mode = 'select'

# %% [markdown]
# ### Compute Embedding in bounding box

# %%
# Compute 2D embeddings
patch_embedding_results = fob.compute_visualization(dataset, patches_field='ground_truth', model=model)
# prediction_embedding_results = fob.compute_visualization(dataset, patches_field='predictions', model=model)

# %% [markdown]
# ### Evaluate Results based on COCO format

# %%
# Evaluate detections in the `predictions` field
# classwise=False, match highest IOU prediction with gt then if class match true-positive else false-positive
# classwise=True, first find prediction bbox same label with gt and IOU>thresh, then if prediction exists, t-p
confusion_results = dataset.evaluate_detections("predictions", gt_field="ground_truth",method="coco",
    classwise=False)

# The top-10 most common classes
counts = dataset.count_values("ground_truth.detections.label")
classes = sorted(counts, key=counts.get, reverse=True)[:10]

# %%
# Compute Class-wise AP50
map_results = dataset.evaluate_detections("predictions", gt_field="ground_truth",method="open-images", iou=0.5)

# %% [markdown]
# ## FiftyOne Evaluation Key

# %%
dataset.evaluate_detections(
    "predictions", gt_field="ground_truth", eval_key="eval"
)

# based on evaluataion, set tp, fn, tn to each patch
eval_patches = dataset.to_evaluation_patches("eval")

# %%
dataset.evaluate_detections(
    "predictions", gt_field="ground_truth", eval_key="eval_non_class", classwise=False
)

# based on evaluataion, set tp, fn, tn to each patch
eval_patches = dataset.to_evaluation_patches("eval_non_class")

# %% [markdown]
# ## FiftyOne Set Attribute
# ### Compute gt bbox overlap and prediction bbox overlap

# %%
foue.compute_max_ious(dataset, "predictions", attr_name="p_class_wise_max_iou", classwise=True)
foue.compute_max_ious(dataset, "predictions", attr_name="p_instance_max_iou", classwise=False)
foue.compute_max_ious(dataset, "ground_truth", attr_name="gt_class_wise_max_iou", classwise=True)
foue.compute_max_ious(dataset, "ground_truth", attr_name="gt_instance_max_iou", classwise=False)

# %%
dups_view = dataset.filter_labels("ground_truth", F("p_class_wise_max_iou") > 0.75)

# %%
dups_view = dataset.filter_labels("ground_truth", F("gt_class_wise_max_iou") > 0.7)
session = fo.launch_app(dataset,view=dups_view,port=5151)

# %% [markdown]
# ## Visualize
# ### GT patch embedding with UMAP

# %%
# Visualize embeddings, colored by ground truth label
umap_plot = patch_embedding_results.visualize(labels="ground_truth.detections.label")
umap_plot.show(height=720)

session.plots.attach(umap_plot)

# %% [markdown]
# ### prediction patch embedding with UMAP (color : overlap iou, size : confidence score)

# %%
# Visualize embeddings, colored by ground truth label
umap_plot = prediction_embedding_results.visualize(labels="predictions.detections.p_instance_max_iou",sizes='predictions.detections.confidence')
umap_plot.show(height=720)

session.plots.attach(umap_plot)

# %% [markdown]
# ### Confusion Matrix to evaluate the model

# %%
# Plot confusion matrix
confusion_plot = confusion_results.plot_confusion_matrix(classes=classes)
confusion_plot.show()

# Connect to FiftyOne App for Interaction
session.plots.attach(confusion_plot)

# Interactive Mode
confusion_plot.selection_mode = 'select'

# %% [markdown]
# ### PR Curve in AP50 for each class

# %%
plot = map_results.plot_pr_curves(classes=classes)
plot.show()

# %%
# Compute Class-wise AP50
map_results = dataset.evaluate_detections("predictions_cls_nms", gt_field="ground_truth",method="open-images", iou=0.5)
plot = map_results.plot_pr_curves(classes=classes)
plot.show()
